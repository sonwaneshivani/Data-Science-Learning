# %% [markdown]
# PANDAS : Library, simple to implement
# * we can read, manipulate data
# * Can perform eda operations
# * Pandas and SQL Always works with structured(tabular) data to perform operations.
# * All sql operations are also done with pandas easily
# * By default(it will be infer) frst row is considered as header
# * If we change header==None then frst row will not be considered as header but as a part of data. It gives index as 0,1...

# %%
import pandas as pd

# %% [markdown]
# Reading CSV data

# %%
pd.read_csv('police.csv',header=None)
# Out:
# C:\Users\SHIVANI\AppData\Local\Temp\ipykernel_35076\898903267.py:1: DtypeWarning: Columns (2,4,5,9,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('police.csv',header=None)
#                0          1            2              3               4   \
# 0       stop_date  stop_time  county_name  driver_gender  driver_age_raw
# 1      2005-01-02      01:55          NaN              M          1985.0
# 2      2005-01-18      08:15          NaN              M          1965.0
# 3      2005-01-23      23:15          NaN              M          1972.0
# 4      2005-02-20      17:15          NaN              M          1986.0
# ...           ...        ...          ...            ...             ...
# 91737  2015-12-31      20:27          NaN              M          1986.0
# 91738  2015-12-31      20:35          NaN              F          1982.0
# 91739  2015-12-31      20:45          NaN              M          1992.0
# ...

# %%
pd.read_csv('police.csv')
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df = pd.read_csv('police.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['stop_date',
#  'stop_time',
#  'county_name',
#  'driver_gender',
#  'driver_age_raw',
#  'driver_age',
#  'driver_race',
#  'violation_raw',
#  'violation',
#  'search_conducted',
#  'search_type',
#  'stop_outcome',
#  'is_arrested',
#  'stop_duration',
#  'drugs_related_stop']

# %% [markdown]
# In pandas majorly there are two datatypes : 1.Series(Same as list, it gives indexes as well) and 2.Dataframe(Tabular structure of the dataset)
# * head : by default first five records
# * tail : by default last five records

# %%
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df.head(12)
# Out:
#      stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0   2005-01-02     01:55          NaN             M          1985.0
# 1   2005-01-18     08:15          NaN             M          1965.0
# 2   2005-01-23     23:15          NaN             M          1972.0
# 3   2005-02-20     17:15          NaN             M          1986.0
# 4   2005-03-14     10:00          NaN             F          1984.0
# 5   2005-03-23     09:45          NaN             M          1982.0
# 6   2005-04-01     17:30          NaN             M          1969.0
# 7   2005-06-06     13:20          NaN             F          1986.0
# 8   2005-07-13     10:15          NaN             M          1970.0
# 9   2005-07-13     15:45          NaN             M          1970.0
# 10  2005-07-13     16:20          NaN             M          1979.0
# 11  2005-07-13     19:00          NaN             F          1966.0
#
#     driver_age driver_race                   violation_raw  violation  \
# ...

# %%
df.tail()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# ...

# %%
df.tail(3)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race            violation_raw         violation  \
# 91738        23.0       White  Other Traffic Violation  Moving violation
# 91739        22.0       White                 Speeding          Speeding
# 91740        56.0    Hispanic                 Speeding          Speeding
#
#        search_conducted search_type stop_outcome is_arrested stop_duration  \
# 91738             False         NaN      Warning       False      0-15 Min
# 91739             False         NaN     Citation       False      0-15 Min
# 91740             False         NaN     Citation       False      0-15 Min
#
#        drugs_related_stop
# 91738               False
# 91739               False
# ...

# %% [markdown]
# To see datatypes of columns

# %%
df.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %% [markdown]
# Accessing details of particular column

# %%
df['drugs_related_stop']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91736    False
# 91737    False
# 91738    False
# 91739    False
# 91740    False
# Name: drugs_related_stop, Length: 91741, dtype: bool

# %% [markdown]
# One single row or one single column is in series

# %%
type(df['drugs_related_stop'])
# Out:
# pandas.core.series.Series

# %%
list(df['drugs_related_stop'])
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %% [markdown]
# Passing as list will be Dataframe

# %%
type(df[['stop_date']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Based on series and dataframe we can perform different operations.

# %% [markdown]
# Selecting multiple columns

# %%
#Gives error cannot pass like this
# We have to pass as list
df['stop_date','stop_time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SHIVANI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\Users\SHIVANI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\SHIVANI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('stop_date', 'stop_time')
#
# ...

# %%
df[['stop_date','stop_time','driver_age_raw', 'driver_age|']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df[['stop_date','stop_time','driver_age_raw', 'driver_age|']]
#
# File c:\Users\SHIVANI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\SHIVANI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %% [markdown]
# Reading Excel data

# %%
df1 = pd.read_excel('youtu.xlsx')

# %%
df1.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df1.tail(12)
# Out:
#        Unnamed: 0       Artist  \
# 20706       20706     ThxSoMch
# 20707       20707     ThxSoMch
# 20708       20708  SICK LEGEND
# 20709       20709  SICK LEGEND
# 20710       20710  SICK LEGEND
# 20711       20711  SICK LEGEND
# 20712       20712  SICK LEGEND
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 20706  https://open.spotify.com/artist/4MvZhE1iuzttco...
# 20707  https://open.spotify.com/artist/4MvZhE1iuzttco...
# 20708  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20709  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20710  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20711  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20712  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %% [markdown]
# Here object means String

# %%
df1.dtypes
# Out:
# Unnamed: 0            int64
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability        float64
# Energy              float64
# Key                 float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed            float64
# official_video      float64
# Stream              float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
df1['Comments']
# Out:
# 0        169907.0
# 1         31003.0
# 2          7399.0
# 3         55229.0
# 4        155930.0
#            ...
# 20713         0.0
# 20714         0.0
# 20715         0.0
# 20716         0.0
# 20717         0.0
# Name: Comments, Length: 20718, dtype: float64

# %%
df1[['Unnamed: 0', 'Artist']]
# Out:
#        Unnamed: 0       Artist
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
# [20718 rows x 2 columns]

# %% [markdown]
# Reading CSV through link

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head(3)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
# 2        33.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False
# 2         NaN     Citation       False      0-15 Min               False

# %%
df.tail(2)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race violation_raw violation  search_conducted  \
# 91739        22.0       White      Speeding  Speeding             False
# 91740        56.0    Hispanic      Speeding  Speeding             False
#
#       search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 91739         NaN     Citation       False      0-15 Min               False
# 91740         NaN     Citation       False      0-15 Min               False

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2['Parch']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64

# %%
df2[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %% [markdown]
# To save this data in our local computer for future reference. As the data is to be loaded everytime

# %%
#This also stores indexes as data
df2.to_csv("titanic_data.csv")

# %% [markdown]
# To save without indexes

# %%
df2.to_csv("titanic_data.csv",index=False)

# %% [markdown]
# On webpage, we have multiple data and we are only interested in tabular data(as pandas only deal with tabular data)
# * On one page there could be many tables
# * To scrap other data we can use beautiful soap as well

# %%
#Only reads table
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %% [markdown]
# In case of many tables it will return a list
# * As one table is kept as dataframe and it will try to put all the dataframes inside the one single list

# %%
type(url_data)
# Out:
# list

# %% [markdown]
# Checking number of tables

# %%
len(url_data)
# Out:
# 1

# %%
df4 = url_data[0]

# %%
df4.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df4.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df4.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df4.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df4['DRB']
# Out:
# 0      222
# 1       19
# 2      324
# 3       54
# 4      220
#       ...
# 670    284
# 671    170
# 672    114
# 673    265
# 674    319
# Name: DRB, Length: 675, dtype: object

# %%
df4[['Rk', 'Player', 'Pos']]
# Out:
#       Rk          Player Pos
# 0      1      Quincy Acy  PF
# 1      2    Jordan Adams  SG
# 2      3    Steven Adams   C
# 3      4     Jeff Adrien  PF
# 4      5   Arron Afflalo  SG
# ..   ...             ...  ..
# 670  490  Thaddeus Young  PF
# 671  490  Thaddeus Young  PF
# 672  490  Thaddeus Young  PF
# 673  491     Cody Zeller   C
# 674  492    Tyler Zeller   C
#
# [675 rows x 3 columns]

# %% [markdown]
# We can also save the data

# %%
df4.to_csv('players.csv',index=False)
